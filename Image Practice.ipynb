# %%
from skimage import data
from skimage.color import rgb2gray
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("hist_image.jpg", mode='r', formats=None)

from skimage import img_as_ubyte,img_as_float
img = rgb2gray(img_as_float(data.chelsea()))  
plt.imshow(img, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-caf3c2700e9e> in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 img = Image.open("hist_image.jpg", mode='r', formats=None)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hist_image.jpg'

# %%
import matplotlib.pyplot as plt
from PIL import Image 

  
# open method used to open different extension image file 
im = Image.open(r"C:\Users\admin\anaconda3\Lib\site-packages\PIL\Aks.jpg")  
  
# This method will show image in any image viewer  
# im.show()

plt.imshow(im, cmap='gray')

# %%
from skimage import data
from skimage.color import rgb2gray
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path

# open method used to open different extension image file 
Aks = Image.open(r"C:\Users\admin\anaconda3\Lib\site-packages\PIL\Aks.jpg") 

from skimage import img_as_ubyte,img_as_float

#imag = rgb2gray(img_as_float(data.chelsea()))  
plt.imshow(Aks, cmap='gray')


  
 
  
# This method will show image in any image viewer  
# im.show()

# plt.imshow(im, cmap='gray')

# %%
Aks.size
# Out:
# (4032, 3024)

# %%
print(Aks.size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5479be4d5dfe> in <module>
# ----> 1 print(Aks.shape)
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
from numpy.linalg import svd

# %%
original_shape = Aks.shape
print(original_shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-1c3b8adba59f> in <module>
# ----> 1 original_shape = Aks.shape
#       2 print(original_shape)
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
from skimage import data
from skimage.color import rgb2gray

from skimage import img_as_ubyte,img_as_float
Retina = rgb2gray(img_as_float(data.retina()))  
plt.imshow(Retina, cmap='gray')

# %%
from numpy.linalg import svd

# %%
original_shape = Retina.shape
print(original_shape)
# Out:
# (1411, 1411)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def compress_svd(image,k):
    U,s,V = svd(image,full_matrices=False)
    reconst_matrix = np.dot(U[:,:k],np.dot(np.diag(s[:k]),V[:k,:]))
   
    return reconst_matrix,s

# %%
k = 100
reconst_img,s = compress_svd(Retina,k)

# %%
print (original_shape[0])
print (original_shape[1])
# Out:
# 1411
# 1411

# %%
fig,axes  = plt.subplots(1,2,figsize =(8,5))
axes[0].plot(s)
# compression_ratio = 100.0*0((k*(original_shape[0] * original_shape[1]))/(original_shape[0]*original_shape[1]))
# print(compression_ratio)
compression_ratio = 100.0*( k*(original_shape[0] + original_shape[1])+k)/(original_shape[0] * original_shape[1])
axes[1].set_title("compression ratio={:.2f}".format(compression_ratio)+"%")
axes[1].imshow(reconst_img, cmap='gray' )
axes[1].axis('off')
# axes[2].imshow(cat_image,cmap='gray' )
# axes[2].axis('off')
fig.tight_layout()

# %%
plt.imshow?
